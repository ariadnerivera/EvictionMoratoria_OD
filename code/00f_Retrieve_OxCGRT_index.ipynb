# %%
#setup
import pandas as pd
import numpy as np
import os

# %%
url='https://raw.githubusercontent.com/OxCGRT/covid-policy-dataset/main/data/OxCGRT_compact_subnational_v1.csv'
df=pd.read_csv(url)
path="C:/Users/rivera30/OneDrive - NYU Langone Health/EvictionMoratoria_OD/"
# Out:
# C:\Users\rivera30\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3526: DtypeWarning: Columns (4,5,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#           CountryName CountryCode RegionName RegionCode CityName CityCode  \
# 0           Australia         AUS        NaN        NaN      NaN      NaN
# 1           Australia         AUS        NaN        NaN      NaN      NaN
# 2           Australia         AUS        NaN        NaN      NaN      NaN
# 3           Australia         AUS        NaN        NaN      NaN      NaN
# 4           Australia         AUS        NaN        NaN      NaN      NaN
# ...               ...         ...        ...        ...      ...      ...
# 239656  United States         USA    Wyoming      US_WY      NaN      NaN
# 239657  United States         USA    Wyoming      US_WY      NaN      NaN
# 239658  United States         USA    Wyoming      US_WY      NaN      NaN
# 239659  United States         USA    Wyoming      US_WY      NaN      NaN
# 239660  United States         USA    Wyoming      US_WY      NaN      NaN
#
#        Jurisdiction      Date  C1M_School.closing  C1M_Flag  ...  \
# ...

# %%
usdf = df[df["CountryName"] == 'United States']

# %%
usdf
# Out:
#           CountryName CountryCode RegionName RegionCode CityName CityCode  \
# 182669  United States         USA        NaN        NaN      NaN      NaN
# 182670  United States         USA        NaN        NaN      NaN      NaN
# 182671  United States         USA        NaN        NaN      NaN      NaN
# 182672  United States         USA        NaN        NaN      NaN      NaN
# 182673  United States         USA        NaN        NaN      NaN      NaN
# ...               ...         ...        ...        ...      ...      ...
# 239656  United States         USA    Wyoming      US_WY      NaN      NaN
# 239657  United States         USA    Wyoming      US_WY      NaN      NaN
# 239658  United States         USA    Wyoming      US_WY      NaN      NaN
# 239659  United States         USA    Wyoming      US_WY      NaN      NaN
# 239660  United States         USA    Wyoming      US_WY      NaN      NaN
#
#        Jurisdiction      Date  C1M_School.closing  C1M_Flag  ...  \
# ...

# %%
counts = usdf["RegionName"].value_counts()

# %%
counts
# Out:
# Alaska            1096
# Pennsylvania      1096
# North Dakota      1096
# Nebraska          1096
# New Hampshire     1096
# New Jersey        1096
# New Mexico        1096
# Nevada            1096
# New York          1096
# Ohio              1096
# Oklahoma          1096
# Oregon            1096
# Rhode Island      1096
# Montana           1096
# South Carolina    1096
# South Dakota      1096
# Tennessee         1096
# Texas             1096
# Utah              1096
# Virginia          1096
# Vermont           1096
# Washington        1096
# Wisconsin         1096
# West Virginia     1096
# North Carolina    1096
# Mississippi       1096
# Alabama           1096
# Iowa              1096
# Arkansas          1096
# Arizona           1096
# California        1096
# Colorado          1096
# Connecticut       1096
# Washington DC     1096
# Delaware          1096
# Florida           1096
# Georgia           1096
# Hawaii            1096
# Idaho             1096
# Missouri          1096
# ...

# %%
usdf2 = usdf.dropna(subset=["RegionName"], how='any')

# %%
usdf2["Date"].value_counts()
# Out:
# 20200101    51
# 20211229    51
# 20220104    51
# 20220103    51
# 20220102    51
#             ..
# 20210106    51
# 20210107    51
# 20210108    51
# 20210109    51
# 20221231    51
# Name: Date, Length: 1096, dtype: int64

# %%
usdf2["Jurisdiction"].value_counts()
# Out:
# STATE_TOTAL    55896
# Name: Jurisdiction, dtype: int64

# %%
usdf2["CityName"].value_counts()
# Out:
# Series([], Name: CityName, dtype: int64)

# %%
usdf2_subset = usdf2[['RegionName', 'StringencyIndex_Average', 'GovernmentResponseIndex_Average', 
                      'ContainmentHealthIndex_Average', 'EconomicSupportIndex', 'Date']]

# %%
usdf2_subset.to_stata(path+"data/2_intermediate/"+"OxCGRT_US"+".dta")

# %%
#usdf2.to_csv(path+"data/2_intermediate/"+"OxCGRT_US"+".csv")

# %%
url1='https://raw.githubusercontent.com/OxCGRT/covid-policy-tracker/master/data/United%20States/OxCGRT_USA_latest.csv'
df1=pd.read_csv(url1)

# %%
df1
# Out:
#          CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 0      United States         USA        NaN        NaN    NAT_TOTAL  20200101
# 1      United States         USA        NaN        NaN    NAT_TOTAL  20200102
# 2      United States         USA        NaN        NaN    NAT_TOTAL  20200103
# 3      United States         USA        NaN        NaN    NAT_TOTAL  20200104
# 4      United States         USA        NaN        NaN    NAT_TOTAL  20200105
# ...              ...         ...        ...        ...          ...       ...
# 56987  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221227
# 56988  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221228
# 56989  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221229
# 56990  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221230
# 56991  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221231
#
# ...

# %%
us_df1 = df1[df1["CountryName"] == 'United States']

# %%
us_df1
# Out:
#          CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 0      United States         USA        NaN        NaN    NAT_TOTAL  20200101
# 1      United States         USA        NaN        NaN    NAT_TOTAL  20200102
# 2      United States         USA        NaN        NaN    NAT_TOTAL  20200103
# 3      United States         USA        NaN        NaN    NAT_TOTAL  20200104
# 4      United States         USA        NaN        NaN    NAT_TOTAL  20200105
# ...              ...         ...        ...        ...          ...       ...
# 56987  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221227
# 56988  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221228
# 56989  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221229
# 56990  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221230
# 56991  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221231
#
# ...

# %%
us_df1_clean = us_df1.dropna(subset=["RegionName"], how='any')

# %%
us_df1_clean
# Out:
#          CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 1096   United States         USA     Alaska      US_AK  STATE_TOTAL  20200101
# 1097   United States         USA     Alaska      US_AK  STATE_TOTAL  20200102
# 1098   United States         USA     Alaska      US_AK  STATE_TOTAL  20200103
# 1099   United States         USA     Alaska      US_AK  STATE_TOTAL  20200104
# 1100   United States         USA     Alaska      US_AK  STATE_TOTAL  20200105
# ...              ...         ...        ...        ...          ...       ...
# 56987  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221227
# 56988  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221228
# 56989  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221229
# 56990  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221230
# 56991  United States         USA    Wyoming      US_WY  STATE_TOTAL  20221231
#
# ...

# %%
us_df1_clean["RegionName"].value_counts()
# Out:
# Alaska            1096
# Pennsylvania      1096
# North Dakota      1096
# Nebraska          1096
# New Hampshire     1096
# New Jersey        1096
# New Mexico        1096
# Nevada            1096
# New York          1096
# Ohio              1096
# Oklahoma          1096
# Oregon            1096
# Rhode Island      1096
# Montana           1096
# South Carolina    1096
# South Dakota      1096
# Tennessee         1096
# Texas             1096
# Utah              1096
# Virginia          1096
# Vermont           1096
# Washington        1096
# Wisconsin         1096
# West Virginia     1096
# North Carolina    1096
# Mississippi       1096
# Alabama           1096
# Iowa              1096
# Arkansas          1096
# Arizona           1096
# California        1096
# Colorado          1096
# Connecticut       1096
# Washington DC     1096
# Delaware          1096
# Florida           1096
# Georgia           1096
# Hawaii            1096
# Idaho             1096
# Missouri          1096
# ...

# %%
us_df1_clean["Date"].value_counts()
# Out:
# 20200101    51
# 20211229    51
# 20220104    51
# 20220103    51
# 20220102    51
#             ..
# 20210106    51
# 20210107    51
# 20210108    51
# 20210109    51
# 20221231    51
# Name: Date, Length: 1096, dtype: int64
